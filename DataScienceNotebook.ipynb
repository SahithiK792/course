# %% [markdown]
# # Data Science Notebook

# %% [markdown]
# ## Data Science Notebook Title

# %% [markdown]
# This notebook contains basic exercises related to Data Science.

# %% [markdown]
# ### Data Science Languages
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ### Data Science Libraries
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# ### Data Science Tools
# | Tool | Category |
# |------|-----------|
# | Jupyter Notebook | IDE |
# | RStudio | IDE |
# | VS Code | Editor |

# %% [markdown]
# Below is an example of simple arithmetic expressions in Python.

# %%
a = 5 * 4
b = a + 10
b

# %%
minutes = 180
hours = minutes / 60
hours

# %% [markdown]
# ### Objectives
# - Introduce Data Science Languages
# - Learn DS Libraries
# - Perform basic arithmetic
# - Convert units
# - Display author details

# %% [markdown]
# **Author:** Sahithi
